# %% [markdown]
# # OHW 2021 - Xtractopy
#
# **Participants:** Andrew Chin, Felippe Galdino, Laura McDonnell, Kyle Oliveira, Bruna Ramos & Jackie Veatch
#
# This Jupyter Notebook outlines the `xtractopy` and `xtractopy2` functions in Python, created during the 2021 Ocean Hack Week. Similar to the R/MATLAB `xtractomatic` package, these functions match tag data from marine animals to broad-scale environmental data from servers, and returns a tidy dataframe that is easily visualized and analyzed in R. To do this, we match `xarray` coordinates to a `pandas` dataframe by consolidating the gridded environmental data into points.
#
# *Inputs:*
# 1. tag data of latitude, longitude, and date/time from the animal in a `pandas` df
# 2. environmental dataset(s) as an `xarray` DataSet
# 3. filename
#
# *Outputs*
# 1. a `.csv` file containing tag coordinates and corresponding environmental variables

# %% [markdown]
# ## Generalized function `xtractopy()`

# %%
# necessary packages
import datetime as dt
import xarray as xr
import numpy as np
import pandas as pd
from typing import Dict, Union
import fsspec
import matplotlib.pyplot as plt
from datetime import datetime

# %%
def xtractopy(envdata,
              tagdata: pd.DataFrame,
             filename: [str]):
    """
    envdata: environmental data in an DataArray format
    tagdata: tag data in a pandas format
    filename: the name of the file .csv output file, as a "string"
    """
    def fuction_dataset_point(**kwargs) -> Dict[str, Union[float, int]]:
        pass

    def extract(function_dataset_point, 
                df: tagdata, 
                map_coordinates: Dict[str, str], 
                rename_variables: Dict[str, str]
               ) -> pd.DataFrame:
        """
        function_dataset_point: environmental data in a point format, to be transformed
        map_coordinates: key is name of column in dataframe, value is the name of the coordinate in dataset
        rename_variables: TBD
        """
    
        def get_row(row) -> Dict[str, Union[float, int]]:
            extract_coordinates = {}
        
            for key, val in map_coordinates.items():
                extract_coordinates[val] = row[key]
                
            print("***********extract_cordates***************")
            print(extract_coordinates)
            print("*****************************")
        
            result = function_dataset_point(**extract_coordinates)
            print("**************result****************")
            print(result)
            print("*************************************")
            # rename variables here and transform result TBD
            return result
        
        temp = df.apply(
            lambda row: get_row(row), axis=1, result_type="expand"
        )
        
        print("*******************************************")
        print("get row function")
        print(pd.DataFrame(temp))
        print("****************************************")
    
        return temp


    def envdata_point(lat, lon, time) -> Dict[str, Union[float, int]]:
        ds = envdata.sel(lat=lat, lon=lon, time=time, method="nearest")

        results = {}
    
        for var in ds.variables:
            if var not in ds.coords:
                results[var] = ds[var].values
    
        return results

    combined_dat = pd.concat([tagdata, 
                        extract(envdata_point,
                                tagdata, 
                                {"lat": "lat", "lon": "lon", "datetime": "time"}, 
                                {}
                               )
                       ], axis=1)
#     combined_dat.to_csv("".join([filename, ".csv"])) # need to figure out how to paste the title into the csv file
    return combined_dat

# %% [markdown]
# ## Tutorial
# Below is an example of an `xtractopy` workflow from OHW 2021. We will be working with tiger sharks (*Galeocerdo cuvier*) tagged in the Gulf Stream system of the Western Atlantic Ocean.
#
# ![tigershark](tigershark_lauramcdonnell.png)
#
# First, let's load in the track data:

# %%
shark_dir = "shark_track_data/track_shark144020.csv"
track_ex = pd.read_csv(shark_dir, parse_dates=['datetime']) # in pandas, read_csv

# track_ex["lon"] = np.where(
#     track_ex["lon"] < 180,
#     track_ex["lon"] + 360,
#     track_ex["lon"])

lat_min = track_ex["lat"].min() - 2.0
lat_max = track_ex["lat"].max() + 2.0
lon_min = track_ex["lon"].min() - 2.0
lon_max = track_ex["lon"].max() + 2.0

xy_bbox = dict(latitude=slice(lat_min,lat_max), longitude=slice(lon_min,lon_max))

plt.plot(track_ex.lon,track_ex.lat)

xy_bbox
# Out:
# /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# {'latitude': slice(24.44818354, 35.90428483, None),
#  'longitude': slice(-82.06428163, -71.04951667, None)}

# %%
track_ex
# Out:
#            lon        lat   datetime
# 0   -78.984392  27.187935 2014-11-15
# 1   -78.952825  27.172386 2014-11-16
# 2   -78.924598  27.156750 2014-11-17
# 3   -78.912462  27.146158 2014-11-18
# 4   -78.929166  27.145738 2014-11-19
# ..         ...        ...        ...
# 367 -78.001361  29.588447 2016-02-27
# 368 -78.335888  29.305051 2016-02-28
# 369 -78.677138  28.971130 2016-02-29
# 370 -79.021606  28.612226 2016-03-01
# 371 -79.366610  28.248083 2016-03-02
#
# [372 rows x 3 columns]

# %%
# grab track data for a few tag datapoints
track_2014 = track_ex.iloc[0:1]
track_2014
# Out:
#          lon        lat   datetime
# 0 -78.984392  27.187935 2014-11-15

# %% [markdown]
# # load in environmental data
# We want to retrieve high resolution data from web repositories and servers and load them into the Python environment as an xarray. In addition, we recommend subsetting the data to the particular study grid for faster run-times. We have a built-in function, `subset_area`, that only requires three simple inputs.
#
# here is the SST from MUR, available [here](https://registry.opendata.aws/mur/).

# %%
# bring in data for SST
file_location = 's3://mur-sst/zarr'
ikey = fsspec.get_mapper(file_location, anon=True)
ds_sst = xr.open_zarr(ikey,consolidated=True)
ds_sst
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 6443, lat: 17999, lon: 36000)
# Coordinates:
#   * lat               (lat) float32 -89.99 -89.98 -89.97 ... 89.97 89.98 89.99
#   * lon               (lon) float32 -180.0 -180.0 -180.0 ... 180.0 180.0 180.0
#   * time              (time) datetime64[ns] 2002-06-01T09:00:00 ... 2020-01-2...
# Data variables:
#     analysed_sst      (time, lat, lon) float32 dask.array<chunksize=(6443, 100, 100), meta=np.ndarray>
#     analysis_error    (time, lat, lon) float32 dask.array<chunksize=(6443, 100, 100), meta=np.ndarray>
#     mask              (time, lat, lon) int8 dask.array<chunksize=(6443, 100, 100), meta=np.ndarray>
#     sea_ice_fraction  (time, lat, lon) float32 dask.array<chunksize=(6443, 100, 100), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:                CF-1.7
#     Metadata_Conventions:       Unidata Observation Dataset v1.0
#     acknowledgment:             Please acknowledge the use of these data with...
#     cdm_data_type:              grid
#     comment:                    MUR = "Multi-scale Ultra-high Resolution"
#     creator_email:              ghrsst@podaac.jpl.nasa.gov
#     ...                         ...
#     summary:                    A merged, multi-sensor L4 Foundation SST anal...
#     time_coverage_end:          20200116T210000Z
#     time_coverage_start:        20200115T210000Z
#     title:                      Daily MUR SST, Final product
#     uuid:                       27665bc0-d5fc-11e1-9b23-0800200c9a66
#     westernmost_longitude:      -180.0

# %%
# Out:
# <bound method Mapping.keys of <fsspec.mapping.FSMap object at 0x7fa040200210>>

# %% [markdown]
# Identify the longitudinal extent of your study area:

# %%
# Subset of Gulf Stream 
max_lon_glf = -70
min_lon_glf = -82

# %% [markdown]
# ### generalized data subset function

# %%
def subset_area(env_data,
                max_lon,
                min_lon):
    subset_lon = (env_data.lon >= min_lon) & (env_data.lon <= max_lon)
    subset_env_data = env_data.where(subset_lon, drop=True)
    return subset_env_data

# %%
gulf_stream_sst = subset_area(ds_sst, max_lon_glf, min_lon_glf)
gulf_stream_sst
# Out:
# <xarray.Dataset>
# Dimensions:           (time: 6443, lat: 17999, lon: 1201)
# Coordinates:
#   * lat               (lat) float32 -89.99 -89.98 -89.97 ... 89.97 89.98 89.99
#   * lon               (lon) float32 -82.0 -81.99 -81.98 ... -70.02 -70.01 -70.0
#   * time              (time) datetime64[ns] 2002-06-01T09:00:00 ... 2020-01-2...
# Data variables:
#     analysed_sst      (time, lat, lon) float32 dask.array<chunksize=(6443, 100, 1), meta=np.ndarray>
#     analysis_error    (time, lat, lon) float32 dask.array<chunksize=(6443, 100, 1), meta=np.ndarray>
#     mask              (time, lat, lon) float64 dask.array<chunksize=(6443, 100, 1), meta=np.ndarray>
#     sea_ice_fraction  (time, lat, lon) float32 dask.array<chunksize=(6443, 100, 1), meta=np.ndarray>
# Attributes: (12/47)
#     Conventions:                CF-1.7
#     Metadata_Conventions:       Unidata Observation Dataset v1.0
#     acknowledgment:             Please acknowledge the use of these data with...
#     cdm_data_type:              grid
#     comment:                    MUR = "Multi-scale Ultra-high Resolution"
#     creator_email:              ghrsst@podaac.jpl.nasa.gov
#     ...                         ...
#     summary:                    A merged, multi-sensor L4 Foundation SST anal...
#     time_coverage_end:          20200116T210000Z
#     time_coverage_start:        20200115T210000Z
#     title:                      Daily MUR SST, Final product
#     uuid:                       27665bc0-d5fc-11e1-9b23-0800200c9a66
#     westernmost_longitude:      -180.0

# %% [markdown]
# ## Additional environmental variables and resultant processing
# here is the SSH and velocity from CMEMS, available [here](https://resources.marine.copernicus.eu/?option=com_csw&view=details&product_id=SEALEVEL_GLO_PHY_L4_REP_OBSERVATIONS_008_047). Note you must create an free account before accessing the data. For these data you must download it to your local repo before calling it into Python.

# %%
# ds_ssh = xr.open_dataset("ssh_data.nc")
# # Converting the lat lon to -180 180
# with xr.set_options(keep_attrs=True):
#     ds_ssh = ds_ssh.assign({'longitude':(((ds_ssh.longitude + 180) % 360) - 180)})

# %% [markdown]
# **BEFORE RUNNING \[VERY IMPORTANT\]:** you must rename the coordinates of the environmental xArray to **"lat"**, **"lon"** and **"time"**, otherwise the code may not run. *Editor's Note: I want to integrate this into the function itself (possibly using a "if-else" loop) But is it worth the effort vs hard-coding one line. thoughts?*. Template code for renaming coordinates:

# %%
ds_ssh_renamed = ds_ssh.rename({'latitude':'lat', 'longitude':'lon', 'time':'time'}) # "old name" : "new name"
ds_ssh_renamed

# %%
gulf_stream_ssh = subset_area(ds_ssh_renamed, max_lon_glf, min_lon_glf)
gulf_stream_ssh

# %%
# for elm in gulf_stream_sst.variables:
#     print(elm)
    

results = {}
    
for var in gulf_stream_sst.variables:
    if var not in gulf_stream_sst.coords:
        results[var] = gulf_stream_sst[var].values
    
results

# %% [markdown]
# here is the Ocean Color data from MODISA, accessed via OpenDap

# %%
# calculate year day for time range of tagged data
day_list = []
year_list = []
for index, row in track_ex.iterrows():
    row_time = pd.to_datetime(row["datetime"])
    day_of_year = datetime(row_time.year, row_time.month, row_time.day).timetuple().tm_yday
    year_list.append(row_time.year)
    day_list.append(day_of_year)

day_string = []
k =0
for day in day_list:
    if day < 10: ### AAAAAGGGGGGHHHHHH
        day_string.append('00'+str(day_list[k]))
    elif day < 100:
        day_string.append('0'+str(day_list[k]))
    else:
        day_string.append(str(day_list[k]))
    k = k+1
    
year_string = [str(x) for x in year_list]


# create access url for ocean color on opendap, merge datafiles to xarray
url = []
base_dir = 'https://oceandata.sci.gsfc.nasa.gov/opendap/hyrax/MODISA/L3SMI/'
suffix = '.L3m_DAY_CHL_chlor_a_4km.nc'

k = 0
for day in day_string:
    url.append('https://oceandata.sci.gsfc.nasa.gov:443/opendap/MODISA/L3SMI/' + year_string[k] +'/' + day + '/A'+year_string[k] + day + '.L3m_DAY_CHL_chlor_a_4km.nc')
    k = k+1

def add_id(ds):
    ds.coords['time_coverage_start'] = pd.to_datetime(ds.attrs['time_coverage_start'])
    return ds

chl = xr.open_mfdataset(url, combine = 'nested', concat_dim='time_coverage_start', preprocess=add_id)
chl = chl.sel( lat=slice(lat_max, lat_min), lon=slice(lon_min,lon_max)) # these data have the lat indexed backwards... no idea why, but it works this way
chl

# %% [markdown]
# spatial mean of chl, to give context to matched data

# %%
ds_chl_renamed = chl.rename({'lat':'lat', 'lon':'lon', 'time_coverage_start':'time'})
chl_da = ds_chl_renamed.chlor_a
mean = chl_da.mean(dim = ['lat','lon'])
mean_df = mean.to_pandas()

# %%
# %%sh
# pip install pyspark[pandas_on_spark] plotly
# Out:
# Requirement already satisfied: pyspark[pandas_on_spark] in /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages (3.3.0)
# Collecting plotly
#   Downloading plotly-5.10.0-py2.py3-none-any.whl (15.2 MB)
# Requirement already satisfied: py4j==0.10.9.5 in /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages (from pyspark[pandas_on_spark]) (0.10.9.5)
# Requirement already satisfied: pandas>=1.0.5; extra == "pandas_on_spark" in /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages (from pyspark[pandas_on_spark]) (1.3.5)
# Requirement already satisfied: pyarrow>=1.0.0; extra == "pandas_on_spark" in /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages (from pyspark[pandas_on_spark]) (9.0.0)
# Requirement already satisfied: numpy>=1.15; extra == "pandas_on_spark" in /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages (from pyspark[pandas_on_spark]) (1.21.6)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.0.5; extra == "pandas_on_spark"->pyspark[pandas_on_spark]) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.0.5; extra == "pandas_on_spark"->pyspark[pandas_on_spark]) (2019.3)
# Requirement already satisfied: six>=1.5 in /Users/Michelle/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0.5; extra == "pandas_on_spark"->pyspark[pandas_on_spark]) (1.12.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.10.0 tenacity-8.1.0
# WARNING: You are using pip version 20.0.2; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/Michelle/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

temp = spark.createDataFrame(ds_sst)
temp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-9085ba730db5> in <module>
#       7     .getOrCreate()
#       8
# ----> 9 temp = spark.createDataFrame(ds_sst)
#      10 temp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyspark/sql/session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     893             )
#     894         return self._create_dataframe(
# --> 895             data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#     896         )
#     897
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyspark/sql/session.py in _create_dataframe(self, data, schema, samplingRatio, verifySchema)
#     934             rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#     935         else:
# --> 936             rdd, struct = self._createFromLocal(map(prepare, data), schema)
#     937         assert self._jvm is not None
#     938         jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyspark/sql/session.py in _createFromLocal(self, data, schema)
#     629
#     630         if schema is None or isinstance(schema, (list, tuple)):
# --> 631             struct = self._inferSchemaFromList(data, names=schema)
#     632             converter = _create_converter(struct)
#     633             tupled_data: Iterable[Tuple] = map(converter, data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyspark/sql/session.py in _inferSchemaFromList(self, data, names)
#     517         schema = reduce(
#     518             _merge_type,
# --> 519             (_infer_schema(row, names, infer_dict_as_struct, prefer_timestamp_ntz) for row in data),
#     520         )
#     521         if _has_nulltype(schema):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyspark/sql/session.py in <genexpr>(.0)
#     517         schema = reduce(
#     518             _merge_type,
# --> 519             (_infer_schema(row, names, infer_dict_as_struct, prefer_timestamp_ntz) for row in data),
#     520         )
#     521         if _has_nulltype(schema):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyspark/sql/types.py in _infer_schema(row, names, infer_dict_as_struct, prefer_timestamp_ntz)
#    1300
#    1301     else:
# -> 1302         raise TypeError("Can not infer schema for type: %s" % type(row))
#    1303
#    1304     fields = []
#
# TypeError: Can not infer schema for type: <class 'str'>

# %%
gulf_stream_sst
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1394         try:
# -> 1395             variable = self._variables[name]
#    1396         except KeyError:
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-7405e276254a> in <module>
# ----> 1 gulf_stream_sst[0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xarray/core/dataset.py in __getitem__(self, key)
#    1497
#    1498         if hashable(key):
# -> 1499             return self._construct_dataarray(key)
#    1500         else:
#    1501             return self._copy_listed(key)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1396         except KeyError:
#    1397             _, name, variable = _get_virtual_variable(
# -> 1398                 self._variables, name, self._level_coords, self.dims
#    1399             )
#    1400
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xarray/core/dataset.py in _get_virtual_variable(variables, key, level_vars, dim_sizes)
#     153
#     154     if not isinstance(key, str):
# --> 155         raise KeyError(key)
#     156
#     157     split_key = key.split(".", 1)
#
# KeyError: 0

# %%
# test
xtractopy(gulf_stream_sst, track_2014, "shark144020_2014_sst")
# xtractopy(ds_ssh_renamed, track_2014, "test_ssh")
# xtractopy(ds_chl_renamed, track_2014, "test_chla")
# Out:
# ***********extract_cordates***************
# {'lat': 27.18793505, 'lon': -78.98439223, 'time': Timestamp('2014-11-15 00:00:00')}
# *****************************
# **************result****************
# {'analysed_sst': array(297.909, dtype=float32), 'analysis_error': array(0.38, dtype=float32), 'mask': array(1, dtype=int8), 'sea_ice_fraction': array(-1.28, dtype=float32)}
# *************************************
# *******************************************
# get row function
#   analysed_sst analysis_error mask sea_ice_fraction
# 0      297.909           0.38    1            -1.28
# ****************************************
#          lon        lat   datetime analysed_sst analysis_error mask  \
# 0 -78.984392  27.187935 2014-11-15      297.909           0.38    1
#
#   sea_ice_fraction
# 0            -1.28

# %% [markdown]
# #### calculate magnitude and eddy index from SSH data
# combined_dat['mag'] = (combined_dat.ugos**2 + combined_dat.vgos**2) ** 0.5
# combined_dat['EKE'] = 0.5 * (combined_dat.ugosa**2 + combined_dat.vgosa**2)
# combined_dat

# %% [markdown]
# # Extract two environmental variables with `xtractopy2` function
# This function is the same as `xtractopy` but accepts two environmental data xArrays.

# %%
def xtractopy2(envdata1,
              envdata2,
              tagdata: pd.DataFrame,
             filename: [str]):
    """
    envdata: environmental data in an DataArray format
    tagdata: tag data in a pandas format
    filename: the name of the file .csv output file, as a "string"
    """
    def fuction_dataset_point(**kwargs) -> Dict[str, Union[float, int]]:
        pass

    def extract(function_dataset_point, 
                df: tagdata, 
                map_coordinates: Dict[str, str], 
                rename_variables: Dict[str, str]
               ) -> pd.DataFrame:
        """
        function_dataset_point: environmental data in a point format, to be transformed
        map_coordinates: key is name of column in dataframe, value is the name of the coordinate in dataset
        rename_variables: TBD
        """
    
        def get_row(row) -> Dict[str, Union[float, int]]:
            extract_coordinates = {}
        
            for key, val in map_coordinates.items():
                extract_coordinates[val] = row[key]
        
            result = function_dataset_point(**extract_coordinates)
        
            # rename variables here and transform result TBD
            return result
    
        return df.apply(
            lambda row: get_row(row), axis=1, result_type="expand"
        )


    def envdata1_point(lat, lon, time) -> Dict[str, Union[float, int]]:
        ds = envdata1.sel(lat=lat, lon=lon, time=time, method="nearest")

        results = {}
    
        for var in ds.variables:
            if var not in ds.coords:
                results[var] = ds[var].values
        return results
    
    def envdata2_point(lat, lon, time) -> Dict[str, Union[float, int]]:
        ds = envdata2.sel(lat=lat, lon=lon, time=time, method="nearest")

        results = {}
    
        for var in ds.variables:
            if var not in ds.coords:
                results[var] = ds[var].values
        return results

    combined2_dat = pd.concat([tagdata, 
                        extract(envdata1_point,
                                tagdata, 
                                {"lat": "lat", "lon": "lon", "datetime": "time"}, 
                                {}
                               ),
                        extract(envdata2_point,
                                tagdata, 
                                {"lat": "lat", "lon": "lon", "datetime": "time"}, 
                                {}
                               )
                       ], axis=1)
    combined2_dat.to_csv("".join([filename, ".csv"])) # need to figure out how to paste the title into the csv file
    return combined2_dat

# %%
xtractopy2(ds_sst, ds_ssh_renamed, track_2014, "test_sst_ssh")
